# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train=pd.read_csv('train-new.csv')
df_test=pd.read_csv('test-new.csv')

# %%
from feature_engine import categorical_encoders as ce
encoder = ce.CountFrequencyCategoricalEncoder(encoding_method='frequency',variables=['dvcat'])

# %%
from feature_engine import categorical_encoders as ce
encoder1 = ce.CountFrequencyCategoricalEncoder(encoding_method='frequency',variables=['dvcat'])
encoder1.fit(df_train)
t_train= encoder1.transform(df_train)
df_train['dvcat_var_imp']=t_train['dvcat']
from feature_engine import categorical_encoders as ce
encoder = ce.CountFrequencyCategoricalEncoder(encoding_method='frequency',variables=['dvcat'])
encoder.fit(df_test)
t_test= encoder.transform(df_test)
df_test['dvcat_var_imp']=t_test['dvcat']

# %%
from feature_engine import categorical_encoders as ce
encoder1 = ce.CountFrequencyCategoricalEncoder(encoding_method='frequency',variables=['dvcat'])
encoder1.fit(df_train)
t_train= encoder1.transform(df_train)
df_train['dvcat_var_imp']=t_train['dvcat']
from feature_engine import categorical_encoders as ce
encoder = ce.CountFrequencyCategoricalEncoder(encoding_method='frequency',variables=['dvcat'])
encoder.fit(df_test)
t_test= encoder.transform(df_test)
df_test['dvcat_var_imp']=t_test['dvcat']

# %%
df_train.corr()
# Out:
#                  weight   frontal  ageOFocc   yearacc   yearVeh    deploy  \
# weight         1.000000 -0.011311 -0.026542  0.008976 -0.009341 -0.055878
# frontal       -0.011311  1.000000 -0.048092  0.017309 -0.022682  0.237448
# ageOFocc      -0.026542 -0.048092  1.000000 -0.006382  0.019544  0.010647
# yearacc        0.008976  0.017309 -0.006382  1.000000  0.297359  0.121288
# yearVeh       -0.009341 -0.022682  0.019544  0.297359  1.000000  0.483176
# deploy        -0.055878  0.237448  0.010647  0.121288  0.483176  1.000000
# injSeverity   -0.207602 -0.019992  0.086280 -0.038700 -0.075241  0.062800
# dvcat_var_imp  0.102782 -0.016501  0.058936  0.028562  0.098176 -0.005886
#
#                injSeverity  dvcat_var_imp
# weight           -0.207602       0.102782
# frontal          -0.019992      -0.016501
# ageOFocc          0.086280       0.058936
# yearacc          -0.038700       0.028562
# yearVeh          -0.075241       0.098176
# deploy            0.062800      -0.005886
# ...

# %%
df_train=df_train.drop([16789])

# %%
from sklearn.preprocessing import LabelEncoder
def preprocessing(data):
    data['yearVeh']=data['yearVeh'].fillna(data['yearVeh'].mode()[0])
#     data['dvcat']=data['dvcat'].map({'1-9km/h':1,'10-24':2,'25-39':3,'40-54':4,'55+':5})
#     data['dead']=data['dead'].map({'dead':0,'alive':1})
    data['age']=data['yearacc']-data['yearVeh']
#     data['airbag']=data['airbag'].map({'none':0,'airbag':1})
#     data['seatbelt']=data['seatbelt'].map({'none':0,'belted':1})
#     data['sex']=data['sex'].map({'f':0,'m':1})
#     data['abcat']=data['abcat'].map({'deploy':0,'unavail':1,'nodeploy':2})
#     data['occRole']=data['occRole'].map({'driver':0,'pass':1})
    data['age']=data['age'].apply(lambda x:0 if(x==-1) else x)
#     data['weight_new']=pd.cut(data['weight'],[-1,60,100,150,480,57871.595],labels=[1,2,3,4,5])
#     data['age_new']=pd.cut(df_train['age'],[0,18,30,40,50,60],labels=[1,2,3,4,5])
    data['caseid_0']=data['caseid'].apply(lambda x:re.findall('[\d]*',x)[0])
    data['caseid_2']=data['caseid'].apply(lambda x:re.findall('[\d]*',x)[2])
    data['caseid_4']=data['caseid'].apply(lambda x:re.findall('[\d]*',x)[4])
    
    
    
    

# def preprocess_label_encode(df_train,df_test):
#     lb=LabelEncoder()
#     lb.fit(df_train['caseid'])
#     df_train['caseid']=lb.transform(df_train['caseid'])
#     df_test['caseid']=lb.transform(df_test['caseid'])

# %%
import re
preprocessing(df_train)
preprocessing(df_test)
# preprocess_label_encode(df_train,df_test)

# %%
df_train
# Out:
#        dvcat    weight   dead  airbag seatbelt  frontal sex  ageOFocc  \
# 0        55+    53.342   dead  airbag   belted        1   f        48
# 1      25-39   154.960  alive    none     none        1   m        26
# 2        55+    38.994  alive    none     none        1   f        51
# 3      25-39   168.568  alive  airbag   belted        1   m        27
# 4      10-24    27.751  alive  airbag   belted        0   m        26
# ...      ...       ...    ...     ...      ...      ...  ..       ...
# 17560  10-24   131.491  alive  airbag   belted        0   m        28
# 17561  10-24   281.693  alive    none   belted        1   f        39
# 17562  10-24   419.418  alive  airbag   belted        1   f        29
# 17563  40-54     9.815  alive    none     none        1   f        22
# 17564  10-24  1395.602  alive    none   belted        1   m        19
#
#        yearacc  yearVeh     abcat occRole  deploy    caseid  injSeverity  \
# ...

# %%
from feature_engine import categorical_encoders as ce
encoder1 = ce.CountFrequencyCategoricalEncoder(encoding_method='frequency',variables=['caseid_2'])
encoder1.fit(df_train)
t_train= encoder1.transform(df_train)
df_train['caseid_2_var_imp']=t_train['caseid_2']
from feature_engine import categorical_encoders as ce
encoder = ce.CountFrequencyCategoricalEncoder(encoding_method='frequency',variables=['caseid_2'])
encoder.fit(df_test)
t_test= encoder.transform(df_test)
df_test['caseid_2_var_imp']=t_test['caseid_2']
df_train['caseid_2']=df_train['caseid_2'].astype(int)
df_test['caseid_2']=df_test['caseid_2'].astype(int)

from feature_engine import categorical_encoders as ce
encoder1 = ce.CountFrequencyCategoricalEncoder(encoding_method='frequency',variables=['caseid_0'])
encoder1.fit(df_train)
t_train= encoder1.transform(df_train)
df_train['caseid_0_var_imp']=t_train['caseid_0']
from feature_engine import categorical_encoders as ce
encoder = ce.CountFrequencyCategoricalEncoder(encoding_method='frequency',variables=['caseid_0'])
encoder.fit(df_test)
t_test= encoder.transform(df_test)
df_test['caseid_0_var_imp']=t_test['caseid_0']
df_train['caseid_0']=df_train['caseid_0'].astype(int)
df_test['caseid_0']=df_test['caseid_0'].astype(int)



from feature_engine import categorical_encoders as ce
encoder1 = ce.CountFrequencyCategoricalEncoder(encoding_method='frequency',variables=['caseid_4'])
encoder1.fit(df_train)
t_train= encoder1.transform(df_train)
df_train['caseid_4_var_imp']=t_train['caseid_4']
from feature_engine import categorical_encoders as ce
encoder = ce.CountFrequencyCategoricalEncoder(encoding_method='frequency',variables=['caseid_4'])
encoder.fit(df_test)
t_test= encoder.transform(df_test)
df_test['caseid_4_var_imp']=t_test['caseid_4']
df_train['caseid_4']=df_train['caseid_4'].astype(int)
df_test['caseid_4']=df_test['caseid_4'].astype(int)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df_train['dvcat']=lb.fit_transform(df_train['dvcat'])
df_test['dvcat']=lb.transform(df_test['dvcat'])
lb=LabelEncoder()
df_train['dead']=lb.fit_transform(df_train['dead'])
df_test['dead']=lb.transform(df_test['dead'])
lb=LabelEncoder()
df_train['airbag']=lb.fit_transform(df_train['airbag'])
df_test['airbag']=lb.transform(df_test['airbag'])
lb=LabelEncoder()
df_train['seatbelt']=lb.fit_transform(df_train['seatbelt'])
df_test['seatbelt']=lb.transform(df_test['seatbelt'])
lb=LabelEncoder()
df_train['sex']=lb.fit_transform(df_train['sex'])
df_test['sex']=lb.transform(df_test['sex'])
lb=LabelEncoder()
df_train['abcat']=lb.fit_transform(df_train['abcat'])
df_test['abcat']=lb.transform(df_test['abcat'])
lb=LabelEncoder()
df_train['occRole']=lb.fit_transform(df_train['occRole'])
df_test['occRole']=lb.transform(df_test['occRole'])

# %%
df_train=df_train.drop(['caseid'],axis=1)
df_test=df_test.drop(['caseid'],axis=1)

# %%
df_train['caseid_2'].nunique()
# Out:
# 328

# %%
# lb=LabelEncoder()
# df_train['weight_new']=lb.fit_transform(df_train['weight_new'])
# df_test['weight_new']=lb.transform(df_test['weight_new'])

# lb=LabelEncoder()
# df_train['age_new']=lb.fit_transform(df_train['age_new'])
# df_test['age_new']=lb.transform(df_test['age_new'])

# %%
# df_train['age_new'].replace({(0, 18]:1},regex=True)

# %% [markdown]
# ### MODEL BUILDING

# %%
from lightgbm import LGBMClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
X=df_train.drop(['injSeverity'],axis=1)
y=df_train.injSeverity

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
lgb_params = {}
lgb_params['learning_rate'] =0.1
lgb_params['boosting_type'] ='gbdt'
lgb_params["subsample"]=1
lgb_params["colsample_bytree"]=.9
lgb_params["min_child_samples"]=20
lgb_params["reg_lambda"]=.1
lgb_params["max_depth"]=15
lgb_params["num_leaves"]=43
lgb_params["n_estimators"]=100
lgb_params["random_state"]=0

# %%
# for i in [1]:
#     print(i)
#     lgb=LGBMClassifier(n_estimators=200,max_depth=i)
#     kfolds=KFold(n_splits=5,shuffle=True,random_state=1)
#     scores_of_model=cross_val_score(lgb,X,y,scoring='f1_weighted',n_jobs=-1)
#     print(np.mean(scores_of_model))
#     print(np.std(scores_of_model))
#     print(scores_of_model)

# %%
# for i in [1]:
#     print('n_estimators',i)
#     gbc=GradientBoostingClassifier(n_estimators=200,max_depth=5)
#     kfolds=KFold(n_splits=3,shuffle=True,random_state=1)
#     scores_of_model=cross_val_score(gbc,X,y,scoring='f1_weighted',n_jobs=-1)
#     print('score',np.mean(scores_of_model))
#     print('var',np.std(scores_of_model))
#     print(scores_of_model)

# %%
gbc=LGBMClassifier(**lgb_params)

# %%
from sklearn.model_selection import train_test_split

# %%
gbc
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=0.9,
#                importance_type='split', learning_rate=0.1, max_depth=15,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=43, objective=None,
#                random_state=0, reg_alpha=0.0, reg_lambda=0.1, silent=True,
#                subsample=1, subsample_for_bin=200000, subsample_freq=0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
gbc.fit(X_train,y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=0.9,
#                importance_type='split', learning_rate=0.1, max_depth=15,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=43, objective=None,
#                random_state=0, reg_alpha=0.0, reg_lambda=0.1, silent=True,
#                subsample=1, subsample_for_bin=200000, subsample_freq=0)

# %%
pd.DataFrame(gbc.feature_importances_,X.columns,columns=['vals']).sort_values(by='vals',ascending=False)
# Out:
#                   vals
# weight            3747
# ageOFocc          3301
# caseid_2          3120
# caseid_2_var_imp  2245
# caseid_0          1971
# caseid_0_var_imp  1874
# yearVeh           1431
# age               1425
# yearacc           1067
# dvcat              774
# sex                491
# seatbelt           448
# caseid_4           418
# frontal            367
# occRole            350
# dvcat_var_imp      338
# abcat              330
# dead               315
# caseid_4_var_imp   139
# airbag             138
# deploy              70

# %%
df_submission=df_test.copy()

# %%
df_test
# Out:
#       dvcat    weight  dead  airbag  seatbelt  frontal  sex  ageOFocc  \
# 0         3    18.895     0       0         0        0    1        25
# 1         2   266.532     0       1         1        1    0        28
# 2         2    51.810     0       0         0        1    0        36
# 3         1  1567.626     0       0         0        0    0        24
# 4         2    31.342     0       1         1        1    0        46
# ...     ...       ...   ...     ...       ...      ...  ...       ...
# 8647      1    64.757     0       0         1        0    1        37
# 8648      0   178.651     0       0         1        1    0        16
# 8649      2   482.272     0       0         0        1    1        16
# 8650      4    32.467     0       1         0        1    1        26
# 8651      3    10.800     1       1         1        0    1        73
#
#       yearacc  yearVeh  ...  occRole  deploy  dvcat_var_imp   age  caseid_0  \
# ...

# %%
df_submission1=pd.DataFrame()
df_submission1['injSeverity']=gbc.predict(df_test)

# %%
df_submission1.to_csv('main5.csv',index=False)
